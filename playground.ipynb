# %%
import training as tr

# %%
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'TSLA',
#   '3. Last Refreshed': '2024-05-02',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2024-05-02': {'1. open': '182.8600',
#    '2. high': '184.6000',
#    '3. low': '176.0200',
#    '4. close': '180.0100',
#    '5. volume': '89148041'},
#   '2024-05-01': {'1. open': '182.0000',
#    '2. high': '185.8600',
#    '3. low': '179.0100',
#    '4. close': '179.9900',
#    '5. volume': '92829719'},
#   '2024-04-30': {'1. open': '186.9800',
#    '2. high': '190.9500',
#    '3. low': '182.8401',
#    '4. close': '183.2800',
#    '5. volume': '127031787'},
#   '2024-04-29': {'1. open': '188.4200',
#    '2. high': '198.8700',
#    '3. low': '184.5400',
#    '4. close': '194.0500',
#    '5. volume': '243869678'},
#   '2024-04-26': {'1. open': '168.8500',
#    '2. high': '172.1200',
#    '3. low': '166.3700',
#    '4. close': '168.2900',
# ...
